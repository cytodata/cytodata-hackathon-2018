# %%
library(tidyverse)
library(cytominer)
library(magrittr)
library(RCurl)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# <U+221A> ggplot2 2.2.1     <U+221A> purrr   0.2.5
# <U+221A> tibble  1.4.2     <U+221A> dplyr   0.7.6
# <U+221A> tidyr   0.8.1     <U+221A> stringr 1.3.1
# <U+221A> readr   1.1.1     <U+221A> forcats 0.2.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Attaching package: 'cytominer'
#
# The following object is masked from 'package:stats':
#
#     aggregate
#
# The following object is masked from 'package:base':
#
#     transform
#
#
# Attaching package: 'magrittr'
#
# The following object is masked from 'package:purrr':
#
#     set_names
#
# The following object is masked from 'package:tidyr':
#
#     extract
#
# Loading required package: bitops
#
# Attaching package: 'RCurl'
#
# The following object is masked from 'package:tidyr':
#
#     complete

# %%
load_dataset  <- function(partition, dataset,feature){
    file_name  <- read_csv("../datasets.csv") 
    x  <-  file_name %>% filter(
         Partition == partition,
         Dataset == dataset,
         Features == feature) %>% 
         extract2("Link")

    return(read_csv(x) %>% 
          mutate(Metadata_dataset = dataset) %>%
          mutate(Metadata_partition = partition) %>% 
          mutate(Metadata_features = feature) 
          )
    }

# %% [markdown]
# # Load data
# We load training and test datasets for both genetic perturbation experiments

# %%
# bbbc37 data 
bbbc037_train  <- load_dataset("Train","BBBC037","DeepLearning")  %>% 
    mutate(Metadata_x_mutation_status = "none")

bbbc037_test <- load_dataset("Test","BBBC037","DeepLearning")  %>% 
    mutate(Metadata_x_mutation_status = "none")

bbbc037  <- rbind(bbbc037_train, bbbc037_test)
# Out:
# Parsed with column specification:
# cols(
#   Dataset = col_character(),
#   Partition = col_character(),
#   Features = col_character(),
#   Link = col_character()
# )
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Metadata_Well = col_character(),
#   Metadata_Plate_Map_Name = col_character(),
#   Metadata_well_position = col_character(),
#   Metadata_gene_name = col_character(),
#   Metadata_pert_name = col_character(),
#   Metadata_broad_sample = col_character(),
#   Metadata_cell_line = col_character(),
#   Metadata_ASSAY_WELL_ROLE = col_character(),
#   Metadata_pert_id = col_character(),
#   Metadata_pert_mfc_id = col_character(),
#   Metadata_pert_well = col_character(),
#   Metadata_pert_id_vendor = col_character(),
#   Metadata_cell_id = col_character(),
#   Metadata_broad_sample_type = col_character(),
#   Metadata_pert_type = col_character(),
#   Plate_Well = col_character(),
#   Metadata_Well.1 = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   Dataset = col_character(),
#   Partition = col_character(),
#   Features = col_character(),
#   Link = col_character()
# )
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Metadata_Plate = col_integer(),
#   Metadata_Well = col_character(),
#   Metadata_Assay_Plate_Barcode = col_integer(),
#   Metadata_Plate_Map_Name = col_character(),
#   Metadata_well_position = col_character(),
#   Metadata_gene_name = col_character(),
#   Metadata_pert_name = col_character(),
#   Metadata_broad_sample = col_character(),
#   Metadata_cell_line = col_character(),
#   Metadata_ASSAY_WELL_ROLE = col_character(),
#   Metadata_pert_id = col_character(),
#   Metadata_pert_mfc_id = col_character(),
#   Metadata_pert_well = col_character(),
#   Metadata_pert_id_vendor = col_character(),
#   Metadata_cell_id = col_character(),
#   Metadata_broad_sample_type = col_character(),
#   Metadata_pert_type = col_character(),
#   Training = col_character(),
#   Plate_Well = col_character(),
#   Metadata_Well.1 = col_character()
# )
# See spec(...) for full column specifications.

# %%
# bbbc043 data 
bbbc043_train  <- load_dataset("Train","BBBC043","DeepLearning")
 
bbbc043_test <- load_dataset("Test","BBBC043","DeepLearning")

bbbc043  <- rbind(bbbc043_train, bbbc043_test)
# Out:
# Parsed with column specification:
# cols(
#   Dataset = col_character(),
#   Partition = col_character(),
#   Features = col_character(),
#   Link = col_character()
# )
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Metadata_Well = col_character(),
#   Metadata_Plate_Map_Name = col_character(),
#   Metadata_well_position = col_character(),
#   Metadata_pert_type = col_character(),
#   Metadata_PublicID = col_character(),
#   Metadata_Transcript = col_character(),
#   Metadata_VirusPlateName = col_character(),
#   Metadata_x_mutation_status = col_character(),
#   Metadata_broad_sample = col_character(),
#   Metadata_pert_name = col_character(),
#   Metadata_pert_id = col_character(),
#   Metadata_pert_mfc_id = col_character(),
#   Metadata_pert_well = col_character(),
#   Metadata_pert_id_vendor = col_character(),
#   Metadata_cell_id = col_character(),
#   Metadata_broad_sample_type = col_character(),
#   Metadata_gene_name = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   Dataset = col_character(),
#   Partition = col_character(),
#   Features = col_character(),
#   Link = col_character()
# )
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Metadata_Plate = col_integer(),
#   Metadata_Well = col_character(),
#   Metadata_Assay_Plate_Barcode = col_integer(),
#   Metadata_Plate_Map_Name = col_character(),
#   Metadata_well_position = col_character(),
#   Metadata_pert_type = col_character(),
#   Metadata_PublicID = col_character(),
#   Metadata_Transcript = col_character(),
#   Metadata_VirusPlateName = col_character(),
#   Metadata_x_mutation_status = col_character(),
#   Metadata_broad_sample = col_character(),
#   Metadata_pert_name = col_character(),
#   Metadata_pert_id = col_character(),
#   Metadata_pert_mfc_id = col_character(),
#   Metadata_pert_well = col_character(),
#   Metadata_pert_id_vendor = col_character(),
#   Metadata_cell_id = col_character(),
#   Metadata_broad_sample_type = col_character(),
#   Metadata_gene_name = col_character(),
#   Metadata_Plate.1 = col_integer()
# )
# See spec(...) for full column specifications.

# %% [markdown]
# ## Check dimensionality

# %%
dim(bbbc043)
dim(bbbc037)
# Out:
# [1] 6144 7704
# [1] 1915 7705

# %% [markdown]
# ## Extract common features

# %%
colnames_bbbc037 <- colnames(bbbc037)
colnames_bbbc043 <- colnames(bbbc043)


Metadata_names_bbbc037 <- c(
   stringr::str_subset(colnames_bbbc037, "^Meta")
) 

Metadata_names_bbbc043 <- c(
   stringr::str_subset(colnames_bbbc043, "^Meta")
) 

common_metadata  <- intersect(Metadata_names_bbbc037, Metadata_names_bbbc043)  
common_features  <- setdiff(intersect(colnames_bbbc037, colnames_bbbc043),common_metadata)

# %% [markdown]
# bbbc037_na_feature  <- cytominer::drop_na_columns(
#     population = bbbc037,
#     variables = common_features,
#     cutoff = 0
#     )
#
# bbbc043_na_feature  <- cytominer::drop_na_columns(
#     population = bbbc043,
#     variables = common_features,
#     cutoff = 0
#     )

# %% [markdown]
# # Concatenate data sets

# %%
population  <- rbind(
    bbbc037 %>% 
        select(c(common_metadata, common_features)),
    bbbc043 %>% 
        select(c(common_metadata, common_features))
    ) %>% 
    mutate(Metadata_perturbation = 'genetic') %>% 
    select(Metadata_perturbation, everything())

# %% [markdown]
# ## Important: update column names!

# %%
colnames_combined  <- colnames(population)

common_metadata  <- c(
   stringr::str_subset(colnames_combined, "^Meta")
) 

common_features  <- setdiff(colnames_combined, common_metadata)

# %% [markdown]
# Cytominer has problems handling column names '1', '2' so we rename them to 'Feature_1', ...

# %%
common_features  <- paste0("Feature_",common_features)
colnames(population)  <- c(common_metadata, common_features)

# %% [markdown]
# # Normalize data
# We use cytominer to normalize both datasets with respect to the controls, i.e. EMPTY genes

# %%
population_normalized  <- cytominer::normalize(
    population, 
    variables = common_features, 
    strata = c("Metadata_perturbation"), 
    sample = population %>% 
                filter(
                    Metadata_gene_name == 'EMPTY',
                    Metadata_partition == "Train"
                ), 
    operation = "standardize"
)

# %%
population_normalized %>% dim() %>% print
# Out:
# [1] 8059 7700

# %% [markdown]
# # Aggregate data

# %%
population_aggregated  <- cytominer::aggregate(
    population = population_normalized, 
    variables = common_features, 
    strata = c("Metadata_gene_name","Metadata_dataset","Metadata_x_mutation_status"), 
    operation = "mean"
)

# %%
population_normalized %>% extract2("Metadata_gene_name") %>% print
# Out:
#    [1] "VEGFC"      "VHL"        "BMPR1B"     "AXIN2"      "BRCA1"
#    [6] "Luciferase" "CASP9"      "AKT3"       "LacZ"       "TBK1"
#   [11] "CDK2"       "IRAK4"      "CDK4"       "ATM"        "CDKN1A"
#   [16] "ATM"        "MAP3K8"     "EMPTY"      "EMPTY"      "EIF2A"
#   [21] "CTNNB1"     "GSK3B"      "PRKCA"      "MAP3K2"     "CARD11"
#   [26] "CARD11"     "XBP1"       "CDC42"      "HSPA5"      "EMPTY"
#   [31] "VHL"        "GSK3B"      "RAC1"       "EIF4E"      "RAC1"
#   [36] "RB1"        "PRKCE"      "LacZ"       "RHOA"       "CREB1"
#   [41] "DVL1"       "EMPTY"      "NOTCH2"     "PIK3R2"     "MAPK14"
#   [46] "PPP2R5C"    "CSNK1E"     "RELA"       "DVL2"       "ADAM17"
#   [51] "EIF4EBP1"   "EMPTY"      "ELK1"       "TGFBR2"     "FH"
#   [56] "EGLN1"      "Luciferase" "RICTOR"     "IKBKB"      "ACVR1B"
#   [61] "IRS1"       "XIAP"       "TGFBR1"     "CDC42"      "BRAF"
#   [66] "TP53"       "SRC"        "CRY1"       "EMPTY"      "HIF1A"
#   [71] "NFKB2"      "RAC1"       "MEK1"       "ERN1"       "Luciferase"
#   [76] "FGFR3"      "RPS6KB1"    "ERG"        "E2F1"       "ERG"
#   [81] "BECN1"      "NOTCH1"     "SMAD4"      "SMAD5"      "CDK2"
#   [86] "NFKBIA"     "CDK4"       "NFKBIB"     "MAPK14"     "PDPK1"
#   [91] "CSNK1E"     "PIK3CB"     "EMPTY"      "PIK3CD"     "ERN1"
#   [96] "PRKACB"     "EMPTY"      "EMPTY"      "JAK2"       "PRKCA"
#  [101] "JUN"        "PRKCE"      "MAP3K5"     "PRKCZ"      "MAP3K11"
#  [106] "MAPK1"      "CEBPA"      "TRAF5"      "CEBPA"      "BMP2"
#  [111] "CREBBP"     "NFKBIE"     "GRB10"      "ATF4"       "EMPTY"
#  [116] "BCL2L1"     "DUSP1"      "Luciferase" "HSP90B1"    "CSNK1A1"
#  [121] "DDIT3"      "YAP1"       "JUN"        "CSNK1A1"    "AXIN2"
#  [126] "YAP1"       "MAPK8"      "PDPK1"      "MAPK9"      "MAPK13"
#  [131] "PIK3CB"     "RELB"       "PIK3R1"     "RHEB"       "PRKAA1"
#  [136] "STAT1"      "PRKACA"     "STAT3"      "LacZ"       "EMPTY"
#  [141] "PRKACB"     "STK11"      "PRKCA"      "TGFBR1"     "PRKCE"
#  [146] "TNFAIP3"    "PRKCZ"      "TRAF2"      "MAPK1"      "PPP2R5C"
#  [151] "APC"        "CTNNB1"     "MAPK7"      "CSNK1A1"    "EMPTY"
#  [156] "LacZ"       "IRAK1"      "YAP1"       "FURIN"      "YAP1"
#  [161] "NFKB1"      "SMAD7"      "JAG1"       "MCL1"       "MAP2K4"
#  [166] "MOS"        "EMPTY"      "PAK1"       "GRB10"      "SOCS3"
#  [171] "AKT3"       "BCL2L11"    "WNT5A"      "MAPK3"      "BTRC"
#  [176] "MAPK8"      "ATG5"       "EMPTY"      "CLOCK"      "MAPK9"
#  [181] "IKBKE"      "MAPK13"     "LacZ"       "DKK1"       "SGK3"
#  [186] "RPS6KB1"    "BAMBI"      "STK3"       "WWTR1"      "STK11"
#  [191] "DDIT4"      "MAP3K7"     "EMPTY"      "TGFBR1"     "HSP90B1"
#  [196] "EMPTY"      "ATG16L1"    "TRAF3"      "HIF1AN"     "MAPKAP1"
#  [201] "CXXC4"      "REL"        "RBPJ"       "CYLD"       "PRKACG"
#  [206] "EMPTY"      "PER1"       "CYLD"       "ATF6"       "MAP2K3"
#  [211] "IRGM"       "PHLPP1"     "MOS"        "EGLN1"      "PAK1"
#  [216] "EGLN1"      "PRKACG"     "PSENEN"     "TGFBR2"     "DIABLO"
#  [221] "MKNK1"      "SMURF2"     "RIPK1"      "XIAP"       "EMPTY"
#  [226] "BMPR1B"     "IKBKE"      "AKT3"       "CRY1"       "LRPPRC"
#  [231] "DDIT3"      "MAP3K2"     "Luciferase" "SGK3"       "DVL3"
#  [236] "TBK1"       "EIF4E"      "XBP1"       "HIF1A"      "XBP1"
#  [241] "TSC1"       "CARD11"     "TSC1"       "EMPTY"      "TRAF6"
#  [246] "PKIA"       "TRAF6"      "PRKACG"     "EMPTY"      "PER1"
#  [251] "BRAF"       "ATF6"       "BRAF"       "AKT1S1"     "NOTCH1"
#  [256] "AKT1S1"     "EMPTY"      "EMPTY"      "NOTCH1"     "IRGM"
#  [261] "SLIRP"      "RBPJ"       "SLIRP"      "DLL1"       "HSP90AA1"
#  [266] "LacZ"       "SMAD3"      "PRKACA"     "NFKB1"      "FURIN"
#  [271] "CHUK"       "PIK3R1"     "MAP3K9"     "EMPTY"      "VEGFC"
#  [276] "PRKAA1"     "CHUK"       "PRKACB"     "EMPTY"      "RAC1"
#  [281] "ACVR1B"     "TGFBR1"     "RB1"        "TCF4"       "RHEB"
#  [286] "DVL1"       "CDK4"       "SMO"        "BMPR1B"     "SMO"
#  [291] "Luciferase" "GLI1"       "RPS6KB1"    "DEPTOR"     "PRKCZ"
#  [296] "DEPTOR"     "PRKCA"      "PPARGC1A"   "PRKCE"      "PPARGC1A"
#  [301] "PRKCZ"      "Luciferase" "STAT1"      "CCNE1"      "MYD88"
#  [306] "MLST8"      "JAK2"       "RPTOR"      "STAT3"      "MYD88"
#  [311] "EMPTY"      "SMAD3"      "SDHA"       "RELA"       "SREBF1"
#  [316] "EIF2A"      "STK3"       "APAF1"      "TCF4"       "Luciferase"
#  [321] "TGFB1"      "MAP2K4"     "TP53"       "TRAF3"      "REL"
#  [326] "eGFP"       "eGFP"       "eGFP"       "eGFP"       "EMPTY"
#  [331] "EMPTY"      "EMPTY"      "EMPTY"      "STAT3"      "FOXO1"
#  [336] "LacZ"       "FOXO1"      "AKT3"       "LacZ"       "BMPR1B"
#  [341] "ACVR1B"     "CDC42"      "ATF6"       "AKT2"       "XBP1"
#  [346] "RHOA"       "RHOA"       "ARNTL"      "eGFP"       "eGFP"
#  [351] "eGFP"       "eGFP"       "EMPTY"      "EMPTY"      "EMPTY"
#  [356] "EMPTY"      "EMPTY"      "EMPTY"      "ATF4"       "TSC2"
#  [361] "BAX"        "VEGFC"      "VHL"        "BMPR1B"     "AXIN2"
#  [366] "BRCA1"      "Luciferase" "CASP9"      "AKT3"       "LacZ"
#  [371] "TBK1"       "CDK2"       "IRAK4"      "CDK4"       "ATM"
#  [376] "CDKN1A"     "ATM"        "MAP3K8"     "EMPTY"      "EMPTY"
#  [381] "EIF2A"      "CTNNB1"     "GSK3B"      "PRKCA"      "MAP3K2"
#  [386] "CARD11"     "CARD11"     "XBP1"       "CDC42"      "HSPA5"
#  [391] "EMPTY"      "VHL"        "GSK3B"      "RAC1"       "EIF4E"
#  [396] "RAC1"       "RB1"        "PRKCE"      "LacZ"       "RHOA"
#  [401] "CREB1"      "DVL1"       "EMPTY"      "NOTCH2"     "PIK3R2"
#  [406] "MAPK14"     "PPP2R5C"    "CSNK1E"     "RELA"       "DVL2"
#  [411] "ADAM17"     "EIF4EBP1"   "EMPTY"      "ELK1"       "TGFBR2"
#  [416] "FH"         "EGLN1"      "Luciferase" "RICTOR"     "IKBKB"
#  [421] "ACVR1B"     "IRS1"       "XIAP"       "TGFBR1"     "CDC42"
#  [426] "BRAF"       "TP53"       "SRC"        "CRY1"       "EMPTY"
#  [431] "HIF1A"      "NFKB2"      "RAC1"       "MEK1"       "ERN1"
#  [436] "Luciferase" "FGFR3"      "RPS6KB1"    "ERG"        "E2F1"
#  [441] "ERG"        "BECN1"      "NOTCH1"     "SMAD4"      "SMAD5"
#  [446] "CDK2"       "NFKBIA"     "CDK4"       "NFKBIB"     "MAPK14"
#  [451] "PDPK1"      "CSNK1E"     "PIK3CB"     "EMPTY"      "PIK3CD"
#  [456] "ERN1"       "PRKACB"     "EMPTY"      "EMPTY"      "JAK2"
#  [461] "PRKCA"      "JUN"        "PRKCE"      "MAP3K5"     "PRKCZ"
#  [466] "MAP3K11"    "MAPK1"      "CEBPA"      "TRAF5"      "CEBPA"
#  [471] "BMP2"       "CREBBP"     "NFKBIE"     "GRB10"      "ATF4"
#  [476] "EMPTY"      "BCL2L1"     "DUSP1"      "Luciferase" "HSP90B1"
#  [481] "CSNK1A1"    "DDIT3"      "YAP1"       "JUN"        "CSNK1A1"
#  [486] "AXIN2"      "YAP1"       "MAPK8"      "PDPK1"      "MAPK9"
#  [491] "MAPK13"     "PIK3CB"     "RELB"       "PIK3R1"     "RHEB"
#  [496] "PRKAA1"     "STAT1"      "PRKACA"     "STAT3"      "LacZ"
#  [501] "EMPTY"      "PRKACB"     "STK11"      "PRKCA"      "TGFBR1"
#  [506] "PRKCE"      "TNFAIP3"    "PRKCZ"      "TRAF2"      "MAPK1"
#  [511] "PPP2R5C"    "APC"        "CTNNB1"     "MAPK7"      "CSNK1A1"
#  [516] "EMPTY"      "LacZ"       "IRAK1"      "YAP1"       "FURIN"
#  [521] "YAP1"       "NFKB1"      "SMAD7"      "JAG1"       "MCL1"
#  [526] "MAP2K4"     "MOS"        "EMPTY"      "PAK1"       "GRB10"
#  [531] "SOCS3"      "AKT3"       "BCL2L11"    "WNT5A"      "MAPK3"
#  [536] "BTRC"       "MAPK8"      "ATG5"       "EMPTY"      "CLOCK"
#  [541] "MAPK9"      "IKBKE"      "MAPK13"     "LacZ"       "DKK1"
#  [546] "SGK3"       "RPS6KB1"    "BAMBI"      "STK3"       "WWTR1"
#  [551] "STK11"      "DDIT4"      "MAP3K7"     "EMPTY"      "TGFBR1"
#  [556] "HSP90B1"    "EMPTY"      "ATG16L1"    "TRAF3"      "HIF1AN"
#  [561] "MAPKAP1"    "CXXC4"      "REL"        "RBPJ"       "CYLD"
#  [566] "PRKACG"     "EMPTY"      "PER1"       "CYLD"       "ATF6"
#  [571] "MAP2K3"     "IRGM"       "PHLPP1"     "MOS"        "EGLN1"
#  [576] "PAK1"       "EGLN1"      "PRKACG"     "PSENEN"     "TGFBR2"
#  [581] "DIABLO"     "MKNK1"      "SMURF2"     "RIPK1"      "XIAP"
#  [586] "EMPTY"      "BMPR1B"     "IKBKE"      "AKT3"       "CRY1"
#  [591] "LRPPRC"     "DDIT3"      "MAP3K2"     "Luciferase" "SGK3"
#  [596] "DVL3"       "TBK1"       "EIF4E"      "XBP1"       "HIF1A"
#  [601] "XBP1"       "TSC1"       "CARD11"     "TSC1"       "EMPTY"
#  [606] "TRAF6"      "PKIA"       "TRAF6"      "PRKACG"     "EMPTY"
#  [611] "PER1"       "BRAF"       "ATF6"       "BRAF"       "AKT1S1"
#  [616] "NOTCH1"     "AKT1S1"     "EMPTY"      "EMPTY"      "NOTCH1"
#  [621] "IRGM"       "SLIRP"      "RBPJ"       "SLIRP"      "DLL1"
#  [626] "HSP90AA1"   "LacZ"       "SMAD3"      "PRKACA"     "NFKB1"
#  [631] "FURIN"      "CHUK"       "PIK3R1"     "MAP3K9"     "EMPTY"
#  [636] "VEGFC"      "PRKAA1"     "CHUK"       "PRKACB"     "EMPTY"
#  [641] "RAC1"       "ACVR1B"     "TGFBR1"     "RB1"        "TCF4"
#  [646] "RHEB"       "DVL1"       "CDK4"       "SMO"        "BMPR1B"
#  [651] "SMO"        "Luciferase" "GLI1"       "RPS6KB1"    "DEPTOR"
#  [656] "PRKCZ"      "DEPTOR"     "PRKCA"      "PPARGC1A"   "PRKCE"
#  [661] "PPARGC1A"   "PRKCZ"      "Luciferase" "STAT1"      "CCNE1"
#  [666] "MYD88"      "MLST8"      "JAK2"       "RPTOR"      "STAT3"
#  [671] "MYD88"      "EMPTY"      "SMAD3"      "SDHA"       "RELA"
#  [676] "SREBF1"     "EIF2A"      "STK3"       "APAF1"      "TCF4"
#  [681] "Luciferase" "TGFB1"      "MAP2K4"     "TP53"       "TRAF3"
#  [686] "REL"        "eGFP"       "eGFP"       "eGFP"       "eGFP"
#  [691] "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"      "STAT3"
#  [696] "FOXO1"      "LacZ"       "FOXO1"      "AKT3"       "LacZ"
#  [701] "BMPR1B"     "ACVR1B"     "CDC42"      "ATF6"       "AKT2"
#  [706] "XBP1"       "RHOA"       "RHOA"       "ARNTL"      "eGFP"
#  [711] "eGFP"       "eGFP"       "eGFP"       "EMPTY"      "EMPTY"
#  [716] "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"      "ATF4"
#  [721] "TSC2"       "BAX"        "VEGFC"      "VHL"        "BMPR1B"
#  [726] "AXIN2"      "BRCA1"      "Luciferase" "CASP9"      "AKT3"
#  [731] "LacZ"       "TBK1"       "CDK2"       "IRAK4"      "CDK4"
#  [736] "ATM"        "CDKN1A"     "ATM"        "MAP3K8"     "EMPTY"
#  [741] "EMPTY"      "EIF2A"      "CTNNB1"     "GSK3B"      "PRKCA"
#  [746] "MAP3K2"     "CARD11"     "CARD11"     "XBP1"       "CDC42"
#  [751] "HSPA5"      "EMPTY"      "VHL"        "GSK3B"      "RAC1"
#  [756] "EIF4E"      "RAC1"       "RB1"        "PRKCE"      "LacZ"
#  [761] "RHOA"       "CREB1"      "DVL1"       "EMPTY"      "NOTCH2"
#  [766] "PIK3R2"     "MAPK14"     "PPP2R5C"    "CSNK1E"     "RELA"
#  [771] "DVL2"       "ADAM17"     "EIF4EBP1"   "EMPTY"      "ELK1"
#  [776] "TGFBR2"     "FH"         "EGLN1"      "Luciferase" "RICTOR"
#  [781] "IKBKB"      "ACVR1B"     "IRS1"       "XIAP"       "TGFBR1"
#  [786] "CDC42"      "BRAF"       "TP53"       "SRC"        "CRY1"
#  [791] "EMPTY"      "HIF1A"      "NFKB2"      "RAC1"       "MEK1"
#  [796] "ERN1"       "Luciferase" "FGFR3"      "RPS6KB1"    "ERG"
#  [801] "E2F1"       "ERG"        "BECN1"      "NOTCH1"     "SMAD4"
#  [806] "SMAD5"      "CDK2"       "NFKBIA"     "CDK4"       "NFKBIB"
#  [811] "MAPK14"     "PDPK1"      "CSNK1E"     "PIK3CB"     "EMPTY"
#  [816] "PIK3CD"     "ERN1"       "PRKACB"     "EMPTY"      "EMPTY"
#  [821] "JAK2"       "PRKCA"      "JUN"        "PRKCE"      "MAP3K5"
#  [826] "PRKCZ"      "MAP3K11"    "MAPK1"      "CEBPA"      "TRAF5"
#  [831] "CEBPA"      "BMP2"       "CREBBP"     "NFKBIE"     "GRB10"
#  [836] "ATF4"       "EMPTY"      "BCL2L1"     "DUSP1"      "Luciferase"
#  [841] "HSP90B1"    "CSNK1A1"    "DDIT3"      "YAP1"       "JUN"
#  [846] "CSNK1A1"    "AXIN2"      "YAP1"       "MAPK8"      "PDPK1"
#  [851] "MAPK9"      "MAPK13"     "PIK3CB"     "RELB"       "PIK3R1"
#  [856] "RHEB"       "PRKAA1"     "STAT1"      "PRKACA"     "STAT3"
#  [861] "LacZ"       "EMPTY"      "PRKACB"     "STK11"      "PRKCA"
#  [866] "TGFBR1"     "PRKCE"      "TNFAIP3"    "PRKCZ"      "TRAF2"
#  [871] "MAPK1"      "PPP2R5C"    "APC"        "CTNNB1"     "MAPK7"
#  [876] "CSNK1A1"    "EMPTY"      "LacZ"       "IRAK1"      "YAP1"
#  [881] "FURIN"      "YAP1"       "NFKB1"      "SMAD7"      "JAG1"
#  [886] "MCL1"       "MAP2K4"     "MOS"        "EMPTY"      "PAK1"
#  [891] "GRB10"      "SOCS3"      "AKT3"       "BCL2L11"    "WNT5A"
#  [896] "MAPK3"      "BTRC"       "MAPK8"      "ATG5"       "EMPTY"
#  [901] "CLOCK"      "MAPK9"      "IKBKE"      "MAPK13"     "LacZ"
#  [906] "DKK1"       "SGK3"       "RPS6KB1"    "BAMBI"      "STK3"
#  [911] "WWTR1"      "STK11"      "DDIT4"      "MAP3K7"     "EMPTY"
#  [916] "TGFBR1"     "HSP90B1"    "EMPTY"      "ATG16L1"    "TRAF3"
#  [921] "HIF1AN"     "MAPKAP1"    "CXXC4"      "REL"        "RBPJ"
#  [926] "CYLD"       "PRKACG"     "EMPTY"      "PER1"       "CYLD"
#  [931] "ATF6"       "MAP2K3"     "IRGM"       "PHLPP1"     "MOS"
#  [936] "EGLN1"      "PAK1"       "EGLN1"      "PRKACG"     "PSENEN"
#  [941] "TGFBR2"     "DIABLO"     "MKNK1"      "SMURF2"     "RIPK1"
#  [946] "XIAP"       "EMPTY"      "BMPR1B"     "IKBKE"      "AKT3"
#  [951] "CRY1"       "LRPPRC"     "DDIT3"      "MAP3K2"     "Luciferase"
#  [956] "SGK3"       "DVL3"       "TBK1"       "EIF4E"      "XBP1"
#  [961] "HIF1A"      "XBP1"       "TSC1"       "CARD11"     "TSC1"
#  [966] "EMPTY"      "TRAF6"      "PKIA"       "TRAF6"      "PRKACG"
#  [971] "EMPTY"      "PER1"       "BRAF"       "ATF6"       "BRAF"
#  [976] "AKT1S1"     "NOTCH1"     "AKT1S1"     "EMPTY"      "EMPTY"
#  [981] "NOTCH1"     "IRGM"       "SLIRP"      "RBPJ"       "SLIRP"
#  [986] "DLL1"       "HSP90AA1"   "LacZ"       "SMAD3"      "PRKACA"
#  [991] "NFKB1"      "FURIN"      "CHUK"       "PIK3R1"     "MAP3K9"
#  [996] "EMPTY"      "VEGFC"      "PRKAA1"     "CHUK"       "PRKACB"
# [1001] "EMPTY"      "RAC1"       "ACVR1B"     "TGFBR1"     "RB1"
# [1006] "TCF4"       "RHEB"       "DVL1"       "CDK4"       "SMO"
# [1011] "BMPR1B"     "SMO"        "Luciferase" "GLI1"       "RPS6KB1"
# [1016] "DEPTOR"     "PRKCZ"      "DEPTOR"     "PRKCA"      "PPARGC1A"
# [1021] "PRKCE"      "PPARGC1A"   "PRKCZ"      "Luciferase" "STAT1"
# [1026] "CCNE1"      "MYD88"      "MLST8"      "JAK2"       "RPTOR"
# [1031] "STAT3"      "MYD88"      "EMPTY"      "SMAD3"      "SDHA"
# [1036] "RELA"       "SREBF1"     "EIF2A"      "STK3"       "APAF1"
# [1041] "TCF4"       "Luciferase" "TGFB1"      "MAP2K4"     "TP53"
# [1046] "TRAF3"      "REL"        "eGFP"       "eGFP"       "eGFP"
# [1051] "eGFP"       "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"
# [1056] "STAT3"      "FOXO1"      "LacZ"       "FOXO1"      "AKT3"
# [1061] "LacZ"       "BMPR1B"     "ACVR1B"     "CDC42"      "ATF6"
# [1066] "AKT2"       "XBP1"       "RHOA"       "RHOA"       "ARNTL"
# [1071] "eGFP"       "eGFP"       "eGFP"       "eGFP"       "EMPTY"
# [1076] "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"
# [1081] "ATF4"       "TSC2"       "BAX"        "VEGFC"      "VHL"
# [1086] "BMPR1B"     "AXIN2"      "BRCA1"      "Luciferase" "CASP9"
# [1091] "AKT3"       "LacZ"       "TBK1"       "CDK2"       "IRAK4"
# [1096] "CDK4"       "ATM"        "CDKN1A"     "ATM"        "MAP3K8"
# [1101] "EMPTY"      "EMPTY"      "EIF2A"      "CTNNB1"     "GSK3B"
# [1106] "PRKCA"      "MAP3K2"     "CARD11"     "CARD11"     "XBP1"
# [1111] "CDC42"      "HSPA5"      "EMPTY"      "VHL"        "GSK3B"
# [1116] "RAC1"       "EIF4E"      "RAC1"       "RB1"        "PRKCE"
# [1121] "LacZ"       "RHOA"       "CREB1"      "DVL1"       "EMPTY"
# [1126] "NOTCH2"     "PIK3R2"     "MAPK14"     "PPP2R5C"    "CSNK1E"
# [1131] "RELA"       "DVL2"       "ADAM17"     "EIF4EBP1"   "EMPTY"
# [1136] "ELK1"       "TGFBR2"     "FH"         "EGLN1"      "Luciferase"
# [1141] "RICTOR"     "IKBKB"      "ACVR1B"     "IRS1"       "XIAP"
# [1146] "TGFBR1"     "CDC42"      "BRAF"       "TP53"       "SRC"
# [1151] "CRY1"       "EMPTY"      "HIF1A"      "NFKB2"      "RAC1"
# [1156] "MEK1"       "ERN1"       "Luciferase" "FGFR3"      "RPS6KB1"
# [1161] "ERG"        "E2F1"       "ERG"        "BECN1"      "NOTCH1"
# [1166] "SMAD4"      "SMAD5"      "CDK2"       "NFKBIA"     "CDK4"
# [1346] "SLIRP"      "DLL1"       "HSP90AA1"   "LacZ"       "SMAD3"
# [1351] "PRKACA"     "NFKB1"      "FURIN"      "CHUK"       "PIK3R1"
# [1356] "MAP3K9"     "EMPTY"      "VEGFC"      "PRKAA1"     "CHUK"
# [1361] "PRKACB"     "EMPTY"      "RAC1"       "ACVR1B"     "TGFBR1"
# [1366] "RB1"        "TCF4"       "RHEB"       "DVL1"       "CDK4"
# [1371] "SMO"        "BMPR1B"     "SMO"        "Luciferase" "GLI1"
# [1376] "RPS6KB1"    "DEPTOR"     "PRKCZ"      "DEPTOR"     "PRKCA"
# [1381] "PPARGC1A"   "PRKCE"      "PPARGC1A"   "PRKCZ"      "Luciferase"
# [1386] "STAT1"      "CCNE1"      "MYD88"      "MLST8"      "JAK2"
# [1391] "RPTOR"      "STAT3"      "MYD88"      "EMPTY"      "SMAD3"
# [1396] "SDHA"       "RELA"       "SREBF1"     "EIF2A"      "STK3"
# [1401] "APAF1"      "TCF4"       "Luciferase" "TGFB1"      "MAP2K4"
# [1406] "TP53"       "TRAF3"      "REL"        "eGFP"       "eGFP"
# [1411] "eGFP"       "eGFP"       "EMPTY"      "EMPTY"      "EMPTY"
# [1416] "EMPTY"      "STAT3"      "FOXO1"      "LacZ"       "FOXO1"
# [1421] "AKT3"       "LacZ"       "BMPR1B"     "ACVR1B"     "CDC42"
# [1426] "ATF6"       "AKT2"       "XBP1"       "RHOA"       "RHOA"
# [1431] "ARNTL"      "eGFP"       "eGFP"       "eGFP"       "eGFP"
# [1436] "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"      "EMPTY"
# [1441] "EMPTY"      "ATF4"       "TSC2"       "BAX"        "VEGFC"
# [1446] "VHL"        "BMPR1B"     "AXIN2"      "BRCA1"      "Luciferase"
# [1451] "CASP9"      "AKT3"       "LacZ"       "TBK1"       "CDK2"
# [1456] "IRAK4"      "CDK4"       "ATM"        "CDKN1A"     "ATM"
# [1461] "MAP3K8"     "EMPTY"      "EMPTY"      "EIF2A"      "CTNNB1"
# [1466] "GSK3B"      "PRKCA"      "MAP3K2"     "CARD11"     "CARD11"
# [1471] "XBP1"       "CDC42"      "HSPA5"      "EMPTY"      "VHL"
# [1476] "GSK3B"      "RAC1"       "EIF4E"      "RAC1"       "RB1"
# [1481] "PRKCE"      "LacZ"       "RHOA"       "CREB1"      "DVL1"
# [1486] "EMPTY"      "NOTCH2"     "PIK3R2"     "MAPK14"     "PPP2R5C"
# [1491] "CSNK1E"     "RELA"       "DVL2"       "ADAM17"     "EIF4EBP1"
# [1496] "EMPTY"      "ELK1"       "TGFBR2"     "FH"         "EGLN1"
# [1501] "Luciferase" "RICTOR"     "IKBKB"      "ACVR1B"     "IRS1"
# [1506] "XIAP"       "TGFBR1"     "CDC42"      "BRAF"       "TP53"
# [1511] "SRC"        "CRY1"       "EMPTY"      "HIF1A"      "NFKB2"
# [1516] "RAC1"       "MEK1"       "ERN1"       "Luciferase" "FGFR3"
# [1521] "RPS6KB1"    "ERG"        "E2F1"       "ERG"        "BECN1"
# [1886] "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"
# [1891] "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"
# [1896] "PTEN"       "PTEN"       "PTEN"       "PTEN"       "PTEN"
# [1901] "RAF1"       "RAF1"       "RAF1"       "RAF1"       "RAF1"
# [1906] "RAF1"       "RAF1"       "RAF1"       "RAF1"       "RAF1"
# [1911] "RAF1"       "RAF1"       "RAF1"       "RAF1"       "RAF1"
# [1916] "EMPTY"      "EMPTY"      "ACAT2"      "EBNA1BP2"   "BFP"
# [1921] "HCRED"      "ABCB9"      "STC2"       "RBM10"      "RBM45"
# [1926] "EGFR"       "PIK3R3"     "KEAP1"      "NUP88"      "GRB7"
# [1931] "AURKB"      "PYGL"       "MTERF3"     "PIH1D1"     "CCL2"
# [1936] "EXOSC4"     "DNTTIP2"    "RHEB"       "EMPTY"      "EMPTY"
# [1941] "TRAP1"      "MFSD10"     "LUCIFERASE" "EGFP"       "CTNNB1"
# [1946] "EGFR"       "EGFR"       "ZBTB24"     "EGFR"       "STK11"
# [1951] "EGFR"       "DNAJC15"    "CDC45"      "NFE2L2"     "MVP"
# [1956] "MRPS16"     "BMP4"       "RNH1"       "DECR1"      "DNMT3A"
# [1961] "FAIM"       "ABCB9"      "STK11"      "EGFP"       "HCRED"
# [1966] "ARAF"       "HAVCR2"     "CTNNB1"     "ZBTB24"     "CTNNB1"
# [1971] "ARAF"       "KEAP1"      "EGFR"       "MAX"        "KEAP1"
# [1976] "PIK3R3"     "RARA"       "EMPTY"      "TPK1"       "KEAP1"
# [1981] "FCGR3B"     "AKT1"       "ZBTB24"     "SERPINB5"   "EMPTY"
# [1986] "KEAP1"      "SERPINB5"   "BFP"        "HCRED"      "FAM173B"
# [1991] "DCAF8"      "HAVCR2"     "ZBTB24"     "RBM45"      "NR4A2"
# [1996] "NR4A2"      "KEAP1"      "KEAP1"      "KEAP1"      "STK11"
# [2001] "KEAP1"      "KEAP1"      "NR4A2"      "EMPTY"      "EMPTY"
# [2006] "RBM34"      "FAM173B"    "SERPINB5"   "EGFR"       "RBM10"
# [2011] "EGFR"       "KEAP1"      "KEAP1"      "HCRED"      "EGFP"
# [2016] "STK11"      "SERPINB5"   "HAVCR2"     "FCGR3B"     "RBM45"
# [2021] "STC2"       "TPK1"       "STC2"       "KEAP1"      "RIT1"
# [2026] "KRAS"       "MDM2"       "EGFR"       "KRAS"       "RIT1"
# [2031] "EGFR"       "TP53"       "STK11"      "PTEN"       "RBM45"
# [2036] "KEAP1"      "KEAP1"      "HCRED"      "LUCIFERASE" "KEAP1"
# [2041] "MAX"        "RBM10"      "RBM45"      "KEAP1"      "EGFR"
# [2046] "NR4A2"      "TERT"       "MDM2"       "NFE2L2"     "KEAP1"
# [2051] "STK11"      "NFE2L2"     "MDM2"       "EGFR"       "EGFR"
# [2056] "TP53"       "TP53"       "RBM10"      "RBM45"      "DCAF8"
# [2061] "KEAP1"      "ABCB9"      "KEAP1"      "HCRED"      "BFP"
# [2066] "KEAP1"      "KEAP1"      "TPK1"       "KEAP1"      "KEAP1"
# [2071] "PSME2"      "SENP6"      "PCCB"       "EMPTY"      "SOX2"
# [2076] "HLA-DRA"    "EMPTY"      "PPARG"      "DAXX"       "PSMG1"
# [2081] "PIK3R3"     "DCAF8"      "NRAS"       "STK11"      "CTNNB1"
# [2086] "STC2"       "EGFP"       "BFP"        "KEAP1"      "NR4A2"
# [2091] "STK11"      "KEAP1"      "RBM45"      "ARAF"       "TSTA3"
# [2096] "GABPB1"     "LAGE3"      "SHC1"       "ID2"        "BRP44"
# [2101] "EMPTY"      "DHRS7"      "HAT1"       "EMPTY"      "KEAP1"
# [2106] "KEAP1"      "RARA"       "FCGR3B"     "STC2"       "EGFR"
# [2111] "KEAP1"      "MYC"        "BFP"        "EGFP"       "DCAF8"
# [2116] "MAX"        "RARA"       "STC2"       "KRAS"       "EGFR"
# [2121] "EGFR"       "KRAS"       "KRAS"       "EGFR"       "KRAS"
# [2126] "EGFR"       "NRAS"       "EGFR"       "RBM10"      "RBM10"
# [2131] "CTNNB1"     "SERPINB5"   "RARA"       "CTNNB1"     "EGFR"
# [2136] "EGFR"       "LUCIFERASE" "HCRED"      "CCND1"      "AKT1"
# [2141] "FCGR3B"     "GOPC"       "KRAS"       "KRAS"       "KRAS"
# [2146] "EGFR"       "EGFR"       "KRAS"       "KRAS"       "KRAS"
# [2151] "EGFR"       "EGFR"       "EGFR"       "RARA"       "KEAP1"
# [2156] "FCGR3B"     "STK11"      "KEAP1"      "EGFR"       "RARA"
# [2161] "STC2"       "STC2"       "LUCIFERASE" "LUCIFERASE" "MYC"
# [2166] "RARA"       "TPK1"       "KEAP1"      "ARAF"       "ZBTB24"
# [2171] "EMPTY"      "RARA"       "TPK1"       "EMPTY"      "SERPINB5"
# [2176] "STK11"      "NR4A2"      "PIK3R3"     "SERPINB5"   "KEAP1"
# [2181] "KEAP1"      "STK11"      "HAVCR2"     "KEAP1"      "KEAP1"
# [2186] "NR4A2"      "BFP"        "LUCIFERASE" "KEAP1"      "NR4A2"
# [2191] "KEAP1"      "DCAF8"      "TPK1"       "EMPTY"      "KEAP1"
# [2196] "KEAP1"      "STK11"      "STK11"      "EMPTY"      "ZBTB24"
# [2201] "KEAP1"      "ARAF"       "STC2"       "FCGR3B"     "KEAP1"
# [2206] "KEAP1"      "NR4A2"      "TPK1"       "KEAP1"      "KEAP1"
# [2211] "PIK3R3"     "ABCB9"      "EGFP"       "BFP"        "MDM2"
# [2216] "NFE2L2"     "STK11"      "EGFR"       "EGFR"       "EGFR"
# [2221] "NFE2L2"     "TP53"       "EGFR"       "KEAP1"      "FCGR3B"
# [2226] "ABCB9"      "EGFR"       "DCAF8"      "HAVCR2"     "KEAP1"
# [2231] "STK11"      "ARAF"       "CTNNB1"     "CTNNB1"     "PIK3R3"
# [2236] "HCRED"      "EGFP"       "STK11"      "KRAS"       "RIT1"
# [2241] "KEAP1"      "EGFR"       "EGFR"       "KRAS"       "EGFR"
# [2246] "EGFR"       "RIT1"       "STK11"      "PTEN"       "NR4A2"
# [2251] "KEAP1"      "CTNNB1"     "CTNNB1"     "MYC"        "KRAS"
# [2256] "HAVCR2"     "RBM10"      "KEAP1"      "EGFR"       "MAX"
# [2261] "RBM45"      "LUCIFERASE" "EGFP"       "KEAP1"      "STK11"
# [2266] "DCAF8"      "EMPTY"      "PIK3R3"     "STK11"      "EMPTY"
# [2271] "ZBTB24"     "TPK1"       "SERPINB5"   "FCGR3B"     "KEAP1"
# [2276] "STC2"       "STK11"      "DCAF8"      "TPK1"       "KEAP1"
# [2281] "ARAF"       "RBM10"      "EGFR"       "SERPINB5"   "KRAS"
# [2286] "EGFP"       "BFP"        "EMPTY"      "STK11"      "FAM173B"
# [2291] "STK11"      "RBM34"      "EMPTY"      "KEAP1"      "EMPTY"
# [2296] "EMPTY"      "ACAT2"      "EBNA1BP2"   "LUCIFERASE" "BFP"
# [2301] "TP53"       "RIT1"       "TP53"       "RB1"        "TP53"
# [2306] "TP53"       "TP53"       "TP53"       "CBR1"       "NFIL3"
# [2311] "RBM15B"     "CSNK1A1"    "NOSIP"      "RBKS"       "CCNH"
# [2316] "CBR3"       "PPOX"       "EMPTY"      "EMPTY"      "TRAP1"
# [2321] "MFSD10"     "HCRED"      "EGFP"       "AKR1B1"     "NFE2L2"
# [2326] "CGREF1"     "RIT1"       "FBXW7"      "MET"        "DOK1"
# [2331] "RAF1"       "CFLAR"      "LIG1"       "FGFR3"      "BRAF"
# [2336] "CD40"       "NFKBIA"     "ACD"        "PWP1"       "ETFB"
# [2341] "NPDC1"      "PIK3CA"     "TP53"       "EGFP"       "BFP"
# [2346] "TP53"       "TP53"       "BRAF"       "U2AF1"      "PPP2R1A"
# [2351] "TP53"       "TP53"       "TP53"       "TP53"       "BRAF"
# [2356] "TP53"       "TP53"       "AKR1B1"     "EMPTY"      "TP53"
# [2361] "MET"        "EMPTY"      "TP53"       "MET"        "TP53"
# [2366] "DOK1"       "PIK3CA"     "LUCIFERASE" "LUCIFERASE" "IDH2"
# [2371] "MAPK7"      "CGREF1"     "PPP2R1A"    "HRAS"       "PIK3CA"
# [2376] "ATF2"       "RAF1"       "BRAF"       "DARC"       "ATF2"
# [2381] "MET"        "MAPK7"      "EMPTY"      "BRAF"       "CGREF1"
# [2386] "EMPTY"      "RIT1"       "TP53"       "TP53"       "TP53"
# [2391] "TP53"       "BFP"        "HCRED"      "TP53"       "TP53"
# [2396] "GPR137B"    "TP53"       "DOK1"       "TP53"       "TP53"
# [2401] "TP53"       "KRAS"       "STK11"      "EGFR"       "RIT1"
# [2406] "NFE2L2"     "KEAP1"      "STK11"      "MDM2"       "EGFR"
# [2411] "EGFR"       "FBXW7"      "CGREF1"     "PPP2R1A"    "AKR1B1"
# [2416] "HCRED"      "HCRED"      "RB1"        "RB1"        "MET"
# [2421] "FGFR3"      "BRAF"       "PPP2R1A"    "GPR137B"    "MAPK7"
# [2426] "EGFR"       "EGFR"       "KRAS"       "RIT1"       "EGFR"
# [2431] "EGFR"       "TP53"       "STK11"      "STK11"      "KEAP1"
# [2436] "TP53"       "TP53"       "TP53"       "TP53"       "TP53"
# [2626] "TP53"       "TP53"       "TP53"       "RIT1"       "TP53"
# [2631] "TP53"       "TP53"       "TP53"       "TP53"       "TP53"
# [2636] "TP53"       "ATF2"       "LUCIFERASE" "LUCIFERASE" "TP53"
# [2641] "PPP2R1A"    "EMPTY"      "TP53"       "TP53"       "TP53"
# [2646] "IDH2"       "EMPTY"      "MET"        "RB1"        "PIK3CA"
# [2651] "PPP2R1A"    "ERBB2"      "AKR1B1"     "MET"        "FBXW7"
# [2656] "SMAD4"      "PIK3CA"     "PPP2R1A"    "IDH2"       "PIK3CA"
# [2661] "MET"        "BFP"        "LUCIFERASE" "RIT1"       "EMPTY"
# [2666] "CASP8"      "DOK1"       "EMPTY"      "ERBB2"      "ATF2"
# [2671] "MDM2"       "EMPTY"      "EMPTY"      "ACAT2"      "EBNA1BP2"
# [2676] "LUCIFERASE" "BFP"        "TP53"       "RIT1"       "TP53"
# [2681] "RB1"        "TP53"       "TP53"       "TP53"       "TP53"
# [2686] "CBR1"       "NFIL3"      "RBM15B"     "CSNK1A1"    "NOSIP"
# [2691] "RBKS"       "CCNH"       "CBR3"       "PPOX"       "EMPTY"
# [2696] "EMPTY"      "TRAP1"      "MFSD10"     "HCRED"      "EGFP"
# [2701] "AKR1B1"     "NFE2L2"     "CGREF1"     "RIT1"       "FBXW7"
# [2706] "MET"        "DOK1"       "RAF1"       "CFLAR"      "LIG1"
# [2711] "FGFR3"      "BRAF"       "CD40"       "NFKBIA"     "ACD"
# [2716] "PWP1"       "ETFB"       "NPDC1"      "PIK3CA"     "TP53"
# [2721] "EGFP"       "BFP"        "TP53"       "TP53"       "BRAF"
# [2726] "U2AF1"      "PPP2R1A"    "TP53"       "TP53"       "TP53"
# [2731] "TP53"       "BRAF"       "TP53"       "TP53"       "AKR1B1"
# [2736] "EMPTY"      "TP53"       "MET"        "EMPTY"      "TP53"
# [2741] "MET"        "TP53"       "DOK1"       "PIK3CA"     "LUCIFERASE"
# [2746] "LUCIFERASE" "IDH2"       "MAPK7"      "CGREF1"     "PPP2R1A"
# [2751] "HRAS"       "PIK3CA"     "ATF2"       "RAF1"       "BRAF"
# [2756] "DARC"       "ATF2"       "MET"        "MAPK7"      "EMPTY"
# [2761] "BRAF"       "CGREF1"     "EMPTY"      "RIT1"       "TP53"
# [2766] "TP53"       "TP53"       "TP53"       "BFP"        "HCRED"
# [2771] "TP53"       "TP53"       "GPR137B"    "TP53"       "DOK1"
# [2776] "TP53"       "TP53"       "TP53"       "KRAS"       "STK11"
# [2781] "EGFR"       "RIT1"       "NFE2L2"     "KEAP1"      "STK11"
# [2786] "MDM2"       "EGFR"       "EGFR"       "FBXW7"      "CGREF1"
# [2791] "PPP2R1A"    "AKR1B1"     "HCRED"      "HCRED"      "RB1"
# [2796] "RB1"        "MET"        "FGFR3"      "BRAF"       "PPP2R1A"
# [2801] "GPR137B"    "MAPK7"      "EGFR"       "EGFR"       "KRAS"
# [2806] "RIT1"       "EGFR"       "EGFR"       "TP53"       "STK11"
# [2811] "STK11"      "KEAP1"      "TP53"       "TP53"       "TP53"
# [3006] "RIT1"       "TP53"       "TP53"       "TP53"       "TP53"
# [3011] "TP53"       "TP53"       "TP53"       "ATF2"       "LUCIFERASE"
# [3016] "LUCIFERASE" "TP53"       "PPP2R1A"    "EMPTY"      "TP53"
# [3021] "TP53"       "TP53"       "IDH2"       "EMPTY"      "MET"
# [3026] "RB1"        "PIK3CA"     "PPP2R1A"    "ERBB2"      "AKR1B1"
# [3031] "MET"        "FBXW7"      "SMAD4"      "PIK3CA"     "PPP2R1A"
# [3036] "IDH2"       "PIK3CA"     "MET"        "BFP"        "LUCIFERASE"
# [3041] "RIT1"       "EMPTY"      "CASP8"      "DOK1"       "EMPTY"
# [3046] "ERBB2"      "ATF2"       "MDM2"       "EMPTY"      "EMPTY"
# [3051] "ACAT2"      "EBNA1BP2"   "BFP"        "HCRED"      "ABCB9"
# [3056] "STC2"       "RBM10"      "RBM45"      "EGFR"       "PIK3R3"
# [3061] "KEAP1"      "NUP88"      "GRB7"       "AURKB"      "PYGL"
# [3066] "MTERF3"     "PIH1D1"     "CCL2"       "EXOSC4"     "DNTTIP2"
# [3071] "RHEB"       "EMPTY"      "EMPTY"      "TRAP1"      "MFSD10"
# [3076] "LUCIFERASE" "EGFP"       "CTNNB1"     "EGFR"       "EGFR"
# [3081] "ZBTB24"     "EGFR"       "STK11"      "EGFR"       "DNAJC15"
# [3086] "CDC45"      "NFE2L2"     "MVP"        "MRPS16"     "BMP4"
# [3091] "RNH1"       "DECR1"      "DNMT3A"     "FAIM"       "ABCB9"
# [3096] "STK11"      "EGFP"       "HCRED"      "ARAF"       "HAVCR2"
# [3101] "CTNNB1"     "ZBTB24"     "CTNNB1"     "ARAF"       "KEAP1"
# [3106] "EGFR"       "MAX"        "KEAP1"      "PIK3R3"     "RARA"
# [3111] "EMPTY"      "TPK1"       "KEAP1"      "FCGR3B"     "AKT1"
# [3116] "ZBTB24"     "SERPINB5"   "EMPTY"      "KEAP1"      "SERPINB5"
# [3121] "BFP"        "HCRED"      "FAM173B"    "DCAF8"      "HAVCR2"
# [3126] "ZBTB24"     "RBM45"      "NR4A2"      "NR4A2"      "KEAP1"
# [3131] "KEAP1"      "KEAP1"      "STK11"      "KEAP1"      "KEAP1"
# [3136] "NR4A2"      "EMPTY"      "EMPTY"      "RBM34"      "FAM173B"
# [3141] "SERPINB5"   "EGFR"       "RBM10"      "EGFR"       "KEAP1"
# [3146] "KEAP1"      "HCRED"      "EGFP"       "STK11"      "SERPINB5"
# [3151] "HAVCR2"     "FCGR3B"     "RBM45"      "STC2"       "TPK1"
# [3156] "STC2"       "KEAP1"      "RIT1"       "KRAS"       "MDM2"
# [3161] "EGFR"       "KRAS"       "RIT1"       "EGFR"       "TP53"
# [3166] "STK11"      "PTEN"       "RBM45"      "KEAP1"      "KEAP1"
# [3171] "HCRED"      "LUCIFERASE" "KEAP1"      "MAX"        "RBM10"
# [3176] "RBM45"      "KEAP1"      "EGFR"       "NR4A2"      "TERT"
# [3181] "MDM2"       "NFE2L2"     "KEAP1"      "STK11"      "NFE2L2"
# [3186] "MDM2"       "EGFR"       "EGFR"       "TP53"       "TP53"
# [3191] "RBM10"      "RBM45"      "DCAF8"      "KEAP1"      "ABCB9"
# [3196] "KEAP1"      "HCRED"      "BFP"        "KEAP1"      "KEAP1"
# [3201] "TPK1"       "KEAP1"      "KEAP1"      "PSME2"      "SENP6"
# [3206] "PCCB"       "EMPTY"      "SOX2"       "HLA-DRA"    "EMPTY"
# [3211] "PPARG"      "DAXX"       "PSMG1"      "PIK3R3"     "DCAF8"
# [3216] "NRAS"       "STK11"      "CTNNB1"     "STC2"       "EGFP"
# [3221] "BFP"        "KEAP1"      "NR4A2"      "STK11"      "KEAP1"
# [3226] "RBM45"      "ARAF"       "TSTA3"      "GABPB1"     "LAGE3"
# [3231] "SHC1"       "ID2"        "BRP44"      "EMPTY"      "DHRS7"
# [3236] "HAT1"       "EMPTY"      "KEAP1"      "KEAP1"      "RARA"
# [3241] "FCGR3B"     "STC2"       "EGFR"       "KEAP1"      "MYC"
# [3246] "BFP"        "EGFP"       "DCAF8"      "MAX"        "RARA"
# [3251] "STC2"       "KRAS"       "EGFR"       "EGFR"       "KRAS"
# [3256] "KRAS"       "EGFR"       "KRAS"       "EGFR"       "NRAS"
# [3261] "EGFR"       "RBM10"      "RBM10"      "CTNNB1"     "SERPINB5"
# [3266] "RARA"       "CTNNB1"     "EGFR"       "EGFR"       "LUCIFERASE"
# [3271] "HCRED"      "CCND1"      "AKT1"       "FCGR3B"     "GOPC"
# [3276] "KRAS"       "KRAS"       "KRAS"       "EGFR"       "EGFR"
# [3281] "KRAS"       "KRAS"       "KRAS"       "EGFR"       "EGFR"
# [3286] "EGFR"       "RARA"       "KEAP1"      "FCGR3B"     "STK11"
# [3291] "KEAP1"      "EGFR"       "RARA"       "STC2"       "STC2"
# [3296] "LUCIFERASE" "LUCIFERASE" "MYC"        "RARA"       "TPK1"
# [3301] "KEAP1"      "ARAF"       "ZBTB24"     "EMPTY"      "RARA"
# [3306] "TPK1"       "EMPTY"      "SERPINB5"   "STK11"      "NR4A2"
# [3311] "PIK3R3"     "SERPINB5"   "KEAP1"      "KEAP1"      "STK11"
# [3316] "HAVCR2"     "KEAP1"      "KEAP1"      "NR4A2"      "BFP"
# [3321] "LUCIFERASE" "KEAP1"      "NR4A2"      "KEAP1"      "DCAF8"
# [3326] "TPK1"       "EMPTY"      "KEAP1"      "KEAP1"      "STK11"
# ...
# [6951] "KEAP1"      "KEAP1"      "HCRED"      "LUCIFERASE" "KEAP1"
# [6956] "MAX"        "RBM10"      "RBM45"      "KEAP1"      "EGFR"
# [6961] "NR4A2"      "TERT"       "MDM2"       "NFE2L2"     "KEAP1"
# [6966] "STK11"      "NFE2L2"     "MDM2"       "EGFR"       "EGFR"
# [6971] "TP53"       "TP53"       "RBM10"      "RBM45"      "DCAF8"
# [6976] "KEAP1"      "ABCB9"      "KEAP1"      "HCRED"      "BFP"
# [6981] "KEAP1"      "KEAP1"      "TPK1"       "KEAP1"      "KEAP1"
# [6986] "PSME2"      "SENP6"      "PCCB"       "EMPTY"      "SOX2"
# [6991] "HLA-DRA"    "EMPTY"      "PPARG"      "DAXX"       "PSMG1"
# [6996] "PIK3R3"     "DCAF8"      "NRAS"       "STK11"      "CTNNB1"
# [7001] "STC2"       "EGFP"       "BFP"        "KEAP1"      "NR4A2"
# [7006] "STK11"      "KEAP1"      "RBM45"      "ARAF"       "TSTA3"
# [7011] "GABPB1"     "LAGE3"      "SHC1"       "ID2"        "BRP44"
# [7016] "EMPTY"      "DHRS7"      "HAT1"       "EMPTY"      "KEAP1"
# [7021] "KEAP1"      "RARA"       "FCGR3B"     "STC2"       "EGFR"
# [7026] "KEAP1"      "MYC"        "BFP"        "EGFP"       "DCAF8"
# [7031] "MAX"        "RARA"       "STC2"       "KRAS"       "EGFR"
# [7036] "EGFR"       "KRAS"       "KRAS"       "EGFR"       "KRAS"
# [7041] "EGFR"       "NRAS"       "EGFR"       "RBM10"      "RBM10"
# [7046] "CTNNB1"     "SERPINB5"   "RARA"       "CTNNB1"     "EGFR"
# [7051] "EGFR"       "LUCIFERASE" "HCRED"      "CCND1"      "AKT1"
# [7056] "FCGR3B"     "GOPC"       "KRAS"       "KRAS"       "KRAS"
# [7061] "EGFR"       "EGFR"       "KRAS"       "KRAS"       "KRAS"
# [7066] "EGFR"       "EGFR"       "EGFR"       "RARA"       "KEAP1"
# [7071] "FCGR3B"     "STK11"      "KEAP1"      "EGFR"       "RARA"
# [7076] "STC2"       "STC2"       "LUCIFERASE" "LUCIFERASE" "MYC"
# [7081] "RARA"       "TPK1"       "KEAP1"      "ARAF"       "ZBTB24"
# [7086] "EMPTY"      "RARA"       "TPK1"       "EMPTY"      "SERPINB5"
# [7091] "STK11"      "NR4A2"      "PIK3R3"     "SERPINB5"   "KEAP1"
# [7096] "KEAP1"      "STK11"      "HAVCR2"     "KEAP1"      "KEAP1"
# [7101] "NR4A2"      "BFP"        "LUCIFERASE" "KEAP1"      "NR4A2"
# [7106] "KEAP1"      "DCAF8"      "TPK1"       "EMPTY"      "KEAP1"
# [7111] "KEAP1"      "STK11"      "STK11"      "EMPTY"      "ZBTB24"
# [7116] "KEAP1"      "ARAF"       "STC2"       "FCGR3B"     "KEAP1"
# [7121] "KEAP1"      "NR4A2"      "TPK1"       "KEAP1"      "KEAP1"
# [7126] "PIK3R3"     "ABCB9"      "EGFP"       "BFP"        "MDM2"
# [7131] "NFE2L2"     "STK11"      "EGFR"       "EGFR"       "EGFR"
# [7136] "NFE2L2"     "TP53"       "EGFR"       "KEAP1"      "FCGR3B"
# [7141] "ABCB9"      "EGFR"       "DCAF8"      "HAVCR2"     "KEAP1"
# [7146] "STK11"      "ARAF"       "CTNNB1"     "CTNNB1"     "PIK3R3"
# [7151] "HCRED"      "EGFP"       "STK11"      "KRAS"       "RIT1"
# [7156] "KEAP1"      "EGFR"       "EGFR"       "KRAS"       "EGFR"
# [7161] "EGFR"       "RIT1"       "STK11"      "PTEN"       "NR4A2"
# [7166] "KEAP1"      "CTNNB1"     "CTNNB1"     "MYC"        "KRAS"
# [7171] "HAVCR2"     "RBM10"      "KEAP1"      "EGFR"       "MAX"
# [7176] "RBM45"      "LUCIFERASE" "EGFP"       "KEAP1"      "STK11"
# [7181] "DCAF8"      "EMPTY"      "PIK3R3"     "STK11"      "EMPTY"
# [7186] "ZBTB24"     "TPK1"       "SERPINB5"   "FCGR3B"     "KEAP1"
# [7191] "STC2"       "STK11"      "DCAF8"      "TPK1"       "KEAP1"
# [7196] "ARAF"       "RBM10"      "EGFR"       "SERPINB5"   "KRAS"
# [7201] "EGFP"       "BFP"        "EMPTY"      "STK11"      "FAM173B"
# [7206] "STK11"      "RBM34"      "EMPTY"      "KEAP1"      "EMPTY"
# [7211] "EMPTY"      "ACAT2"      "EBNA1BP2"   "LUCIFERASE" "BFP"
# [7216] "TP53"       "RIT1"       "TP53"       "RB1"        "TP53"
# [7221] "TP53"       "TP53"       "TP53"       "CBR1"       "NFIL3"
# [7226] "RBM15B"     "CSNK1A1"    "NOSIP"      "RBKS"       "CCNH"
# [7231] "CBR3"       "PPOX"       "EMPTY"      "EMPTY"      "TRAP1"
# [7236] "MFSD10"     "HCRED"      "EGFP"       "AKR1B1"     "NFE2L2"
# [7241] "CGREF1"     "RIT1"       "FBXW7"      "MET"        "DOK1"
# [7246] "RAF1"       "CFLAR"      "LIG1"       "FGFR3"      "BRAF"
# [7251] "CD40"       "NFKBIA"     "ACD"        "PWP1"       "ETFB"
# [7256] "NPDC1"      "PIK3CA"     "TP53"       "EGFP"       "BFP"
# [7261] "TP53"       "TP53"       "BRAF"       "U2AF1"      "PPP2R1A"
# [7266] "TP53"       "TP53"       "TP53"       "TP53"       "BRAF"
# [7271] "TP53"       "TP53"       "AKR1B1"     "EMPTY"      "TP53"
# [7276] "MET"        "EMPTY"      "TP53"       "MET"        "TP53"
# [7281] "DOK1"       "PIK3CA"     "LUCIFERASE" "LUCIFERASE" "IDH2"
# [7286] "MAPK7"      "CGREF1"     "PPP2R1A"    "HRAS"       "PIK3CA"
# [7291] "ATF2"       "RAF1"       "BRAF"       "DARC"       "ATF2"
# [7296] "MET"        "MAPK7"      "EMPTY"      "BRAF"       "CGREF1"
# [7301] "EMPTY"      "RIT1"       "TP53"       "TP53"       "TP53"
# [7306] "TP53"       "BFP"        "HCRED"      "TP53"       "TP53"
# [7311] "GPR137B"    "TP53"       "DOK1"       "TP53"       "TP53"
# [7316] "TP53"       "KRAS"       "STK11"      "EGFR"       "RIT1"
# [7321] "NFE2L2"     "KEAP1"      "STK11"      "MDM2"       "EGFR"
# [7326] "EGFR"       "FBXW7"      "CGREF1"     "PPP2R1A"    "AKR1B1"
# [7331] "HCRED"      "HCRED"      "RB1"        "RB1"        "MET"
# [7336] "FGFR3"      "BRAF"       "PPP2R1A"    "GPR137B"    "MAPK7"
# [7341] "EGFR"       "EGFR"       "KRAS"       "RIT1"       "EGFR"
# [7346] "EGFR"       "TP53"       "STK11"      "STK11"      "KEAP1"
# [7351] "TP53"       "TP53"       "TP53"       "TP53"       "TP53"
# [7356] "PPP2R1A"    "HCRED"      "EGFP"       "TP53"       "TP53"
# [7361] "DARC"       "MDM2"       "TP53"       "IDH2"       "CCDC90A"
# [7556] "PPP2R1A"    "EMPTY"      "TP53"       "TP53"       "TP53"
# [7561] "IDH2"       "EMPTY"      "MET"        "RB1"        "PIK3CA"
# [7566] "PPP2R1A"    "ERBB2"      "AKR1B1"     "MET"        "FBXW7"
# [7571] "SMAD4"      "PIK3CA"     "PPP2R1A"    "IDH2"       "PIK3CA"
# [7576] "MET"        "BFP"        "LUCIFERASE" "RIT1"       "EMPTY"
# [7581] "CASP8"      "DOK1"       "EMPTY"      "ERBB2"      "ATF2"
# [7586] "MDM2"       "EMPTY"      "EMPTY"      "ACAT2"      "EBNA1BP2"
# [7591] "LUCIFERASE" "BFP"        "TP53"       "RIT1"       "TP53"
# [7596] "RB1"        "TP53"       "TP53"       "TP53"       "TP53"
# [7601] "CBR1"       "NFIL3"      "RBM15B"     "CSNK1A1"    "NOSIP"
# [7606] "RBKS"       "CCNH"       "CBR3"       "PPOX"       "EMPTY"
# [7611] "EMPTY"      "TRAP1"      "MFSD10"     "HCRED"      "EGFP"
# [7616] "AKR1B1"     "NFE2L2"     "CGREF1"     "RIT1"       "FBXW7"
# [7621] "MET"        "DOK1"       "RAF1"       "CFLAR"      "LIG1"
# [7626] "FGFR3"      "BRAF"       "CD40"       "NFKBIA"     "ACD"
# [7631] "PWP1"       "ETFB"       "NPDC1"      "PIK3CA"     "TP53"
# [7636] "EGFP"       "BFP"        "TP53"       "TP53"       "BRAF"
# [7641] "U2AF1"      "PPP2R1A"    "TP53"       "TP53"       "TP53"
# [7646] "TP53"       "BRAF"       "TP53"       "TP53"       "AKR1B1"
# [7651] "EMPTY"      "TP53"       "MET"        "EMPTY"      "TP53"
# [7656] "MET"        "TP53"       "DOK1"       "PIK3CA"     "LUCIFERASE"
# [7661] "LUCIFERASE" "IDH2"       "MAPK7"      "CGREF1"     "PPP2R1A"
# [7666] "HRAS"       "PIK3CA"     "ATF2"       "RAF1"       "BRAF"
# [7671] "DARC"       "ATF2"       "MET"        "MAPK7"      "EMPTY"
# [7676] "BRAF"       "CGREF1"     "EMPTY"      "RIT1"       "TP53"
# [7681] "TP53"       "TP53"       "TP53"       "BFP"        "HCRED"
# [7686] "TP53"       "TP53"       "GPR137B"    "TP53"       "DOK1"
# [7691] "TP53"       "TP53"       "TP53"       "KRAS"       "STK11"
# [7696] "EGFR"       "RIT1"       "NFE2L2"     "KEAP1"      "STK11"
# [7701] "MDM2"       "EGFR"       "EGFR"       "FBXW7"      "CGREF1"
# [7706] "PPP2R1A"    "AKR1B1"     "HCRED"      "HCRED"      "RB1"
# [7711] "RB1"        "MET"        "FGFR3"      "BRAF"       "PPP2R1A"
# [7716] "GPR137B"    "MAPK7"      "EGFR"       "EGFR"       "KRAS"
# [7721] "RIT1"       "EGFR"       "EGFR"       "TP53"       "STK11"
# [7726] "STK11"      "KEAP1"      "TP53"       "TP53"       "TP53"
# [7731] "TP53"       "TP53"       "PPP2R1A"    "HCRED"      "EGFP"
# [7736] "TP53"       "TP53"       "DARC"       "MDM2"       "TP53"
# [7931] "LUCIFERASE" "TP53"       "PPP2R1A"    "EMPTY"      "TP53"
# [7936] "TP53"       "TP53"       "IDH2"       "EMPTY"      "MET"
# [7941] "RB1"        "PIK3CA"     "PPP2R1A"    "ERBB2"      "AKR1B1"
# [7946] "MET"        "FBXW7"      "SMAD4"      "PIK3CA"     "PPP2R1A"
# [7951] "IDH2"       "PIK3CA"     "MET"        "BFP"        "LUCIFERASE"
# [7956] "RIT1"       "EMPTY"      "CASP8"      "DOK1"       "EMPTY"
# [7961] "ERBB2"      "ATF2"       "MDM2"       "AKT1"       "AKT1"
# [7966] "AKT1"       "AKT1"       "AKT1"       "AKT1"       "AKT1"
# [7971] "AKT1"       "ARAF"       "ARAF"       "ARAF"       "ARAF"
# [7976] "ARAF"       "ARAF"       "ARAF"       "ARAF"       "ATF2"
# [7981] "ATF2"       "ATF2"       "ATF2"       "ATF2"       "ATF2"
# [7986] "ATF2"       "ATF2"       "CASP8"      "CASP8"      "CASP8"
# [7991] "CASP8"      "CASP8"      "CASP8"      "CASP8"      "CASP8"
# [7996] "CCND1"      "CCND1"      "CCND1"      "CCND1"      "CCND1"
# [8001] "CCND1"      "CCND1"      "CCND1"      "ERBB2"      "ERBB2"
# [8006] "ERBB2"      "ERBB2"      "ERBB2"      "ERBB2"      "ERBB2"
# [8011] "ERBB2"      "HRAS"       "HRAS"       "HRAS"       "HRAS"
# [8016] "HRAS"       "HRAS"       "HRAS"       "HRAS"       "KRAS"
# [8021] "KRAS"       "KRAS"       "KRAS"       "KRAS"       "KRAS"
# [8026] "KRAS"       "KRAS"       "MAP2K1"     "MAP2K1"     "MAP2K1"
# [8031] "MAP2K1"     "MAP2K1"     "MAP2K1"     "MAP2K1"     "MAP2K1"
# [8036] "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"     "PIK3CA"
# [8041] "PIK3CA"     "PIK3CA"     "PIK3CA"     "PTEN"       "PTEN"
# [8046] "PTEN"       "PTEN"       "PTEN"       "PTEN"       "PTEN"
# [8051] "PTEN"       "RAF1"       "RAF1"       "RAF1"       "RAF1"
# [8056] "RAF1"       "RAF1"       "RAF1"       "RAF1"

# %%
population_aggregated %>% slice(1:2) %>% print
# Out:
# # A tibble: 2 x 7,683
#   Metadata_gene_n~ Metadata_dataset Metadata_x_muta~ Feature_0 Feature_1
#   <chr>            <chr>            <chr>                <dbl>     <dbl>
# 1 ABCB9            BBBC043          ABCB9_WT.c           0.569     0.601
# 2 ABCB9            BBBC043          ABCB9_WT.o           0.636     0.578
# # ... with 7,678 more variables: Feature_2 <dbl>, Feature_3 <dbl>,
# #   Feature_4 <dbl>, Feature_5 <dbl>, Feature_6 <dbl>, Feature_7 <dbl>,
# #   Feature_8 <dbl>, Feature_9 <dbl>, Feature_10 <dbl>, Feature_11 <dbl>,
# #   Feature_12 <dbl>, Feature_13 <dbl>, Feature_14 <dbl>, Feature_15 <dbl>,
# #   Feature_16 <dbl>, Feature_17 <dbl>, Feature_18 <dbl>, Feature_19 <dbl>,
# #   Feature_20 <dbl>, Feature_21 <dbl>, Feature_22 <dbl>, Feature_23 <dbl>,
# #   Feature_24 <dbl>, Feature_25 <dbl>, Feature_26 <dbl>, Feature_27 <dbl>,
# #   Feature_28 <dbl>, Feature_29 <dbl>, Feature_30 <dbl>, Feature_31 <dbl>,
# #   Feature_32 <dbl>, Feature_33 <dbl>, Feature_34 <dbl>, Feature_35 <dbl>,
# #   Feature_36 <dbl>, Feature_37 <dbl>, Feature_38 <dbl>, Feature_39 <dbl>,
# #   Feature_40 <dbl>, Feature_41 <dbl>, Feature_42 <dbl>, Feature_43 <dbl>,
# #   Feature_44 <dbl>, Feature_45 <dbl>, Feature_46 <dbl>, Feature_47 <dbl>,
# #   Feature_48 <dbl>, Feature_49 <dbl>, Feature_50 <dbl>, Feature_51 <dbl>,
# #   Feature_52 <dbl>, Feature_53 <dbl>, Feature_54 <dbl>, Feature_55 <dbl>,
# #   Feature_56 <dbl>, Feature_57 <dbl>, Feature_58 <dbl>, Feature_59 <dbl>,
# #   Feature_60 <dbl>, Feature_61 <dbl>, Feature_62 <dbl>, Feature_63 <dbl>,
# #   Feature_64 <dbl>, Feature_65 <dbl>, Feature_66 <dbl>, Feature_67 <dbl>,
# #   Feature_68 <dbl>, Feature_69 <dbl>, Feature_70 <dbl>, Feature_71 <dbl>,
# #   Feature_72 <dbl>, Feature_73 <dbl>, Feature_74 <dbl>, Feature_75 <dbl>,
# #   Feature_76 <dbl>, Feature_77 <dbl>, Feature_78 <dbl>, Feature_79 <dbl>,
# #   Feature_80 <dbl>, Feature_81 <dbl>, Feature_82 <dbl>, Feature_83 <dbl>,
# #   Feature_84 <dbl>, Feature_85 <dbl>, Feature_86 <dbl>, Feature_87 <dbl>,
# #   Feature_88 <dbl>, Feature_89 <dbl>, Feature_90 <dbl>, Feature_91 <dbl>,
# #   Feature_92 <dbl>, Feature_93 <dbl>, Feature_94 <dbl>, Feature_95 <dbl>,
# #   Feature_96 <dbl>, Feature_97 <dbl>, Feature_98 <dbl>, Feature_99 <dbl>,
# #   Feature_100 <dbl>, Feature_101 <dbl>, ...

# %% [markdown]
# # Correlation matrix

# %%
cor_matrix  <- cor(
    x = population_aggregated %>% 
        filter(Metadata_dataset == 'BBBC037') %>% 
        select(common_features) %>% 
        as.matrix() %>% 
        t, 
    y = population_aggregated %>% 
        filter(Metadata_dataset == 'BBBC043') %>% 
        select(common_features) %>% 
        as.matrix() %>% 
        t,
    use  = "complete.obs"
    )

# %% [markdown]
# # Submision file

# %%
# set column names 
colnames(cor_matrix)  <- population_aggregated %>% 
                            filter(Metadata_dataset == 'BBBC043') %>%
                            extract2("Metadata_x_mutation_status")

# set row names 
rownames(cor_matrix)  <- population_aggregated %>% 
                            filter(Metadata_dataset == 'BBBC037') %>%
                            extract2("Metadata_gene_name")


df  <- cor_matrix %>% as_data_frame() %>% 
            mutate(Metadata_gene_name = population_aggregated %>% 
                            filter(Metadata_dataset == 'BBBC037') %>%
                            extract2("Metadata_gene_name")) %>% 
            select(Metadata_gene_name, everything())

# write submission file
write.csv(df,"../cytodata-baseline_R.csv",row.names = FALSE)
